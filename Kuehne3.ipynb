# %%
# %matplotlib inline
from process import get_processed_data, visualize_unknown_data
df = get_processed_data('kuehne_3.csv')
visualize_unknown_data(df)
df.head()
# Out:
# Data Cleaning
# Removing NaN columns
# LocationType only contains NaNs
# Street 2 only contains NaNs
# State/Province code only contains NaNs
#     LocationCode                                           Name  \
# NaT  CADIS-DEBAD  CANADA, BURLINGTON, SAMPLE3 DISTRIBUTION, UPS
# NaT  CADIS-CADXS  CANADA, BURLINGTON, SAMPLE3 DISTRIBUTION, UPS
# NaT  CADIS-AUSIG  CANADA, BURLINGTON, SAMPLE3 DISTRIBUTION, UPS
# NaT  CADIS-FRRSS  CANADA, BURLINGTON, SAMPLE3 DISTRIBUTION, UPS
# NaT  CADIS-IESLI  CANADA, BURLINGTON, SAMPLE3 DISTRIBUTION, UPS
#
#                                               Street 1 PostalCode        City  \
# NaT  (AIR - IMPORTER ID#896922556RM0001) / 4071 NOR...        NaN  BURLINGTON
# NaT  (AIR - IMPORTER ID#896922556RM0001) / 4071 NOR...        NaN  BURLINGTON
# NaT  (AIR - IMPORTER ID#896922556RM0001) / 4071 NOR...        NaN  BURLINGTON
# NaT  (AIR - IMPORTER ID#896922556RM0001) / 4071 NOR...        NaN  BURLINGTON
# NaT  (AIR - IMPORTER ID#896922556RM0001) / 4071 NOR...        NaN  BURLINGTON
#
#     Country Time Zone
# NaT      CA    UTC -5
# NaT      CA    UTC -5
# NaT      CA    UTC -5
# NaT      CA    UTC -5
# NaT      CA    UTC -5

# %%
from process import read_data
df = read_data('cleaned_3.csv')
visualize_unknown_data(df)

# %%
df = read_data('cleaned_and_normalized_3.csv')
visualize_unknown_data(df)
df.head()
# Out:
#      street  street_addition postal_code        city state country  \
# name
# NaN     NaN              NaN         L7R  Burlington    ON     CAN
# NaN     NaN              NaN         L7R  Burlington    ON     CAN
# NaN     NaN              NaN         L7R  Burlington    ON     CAN
# NaN     NaN              NaN         L7R  Burlington    ON     CAN
# NaN     NaN              NaN         L7R  Burlington    ON     CAN
#
#       location_type      lat       lng  standard_opening_times  building_type  \
# name
# NaN             NaN  43.3262 -79.79863                     NaN            NaN
# NaN             NaN  43.3262 -79.79863                     NaN            NaN
# NaN             NaN  43.3262 -79.79863                     NaN            NaN
# NaN             NaN  43.3262 -79.79863                     NaN            NaN
# NaN             NaN  43.3262 -79.79863                     NaN            NaN
#
#      time_zone  access_notes
# name
# NaN     UTC -5           NaN
# NaN     UTC -5           NaN
# NaN     UTC -5           NaN
# NaN     UTC -5           NaN
# NaN     UTC -5           NaN

# %%
#Mit Samples
# %matplotlib inline
from process import read_data
from process import get_processed_data, visualize_unknown_data
df = read_data('cleaned_and_normalized_3.csv')
visualize_unknown_data(df)
df
# Out:
#                                                     street_addition  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...              NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...              NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...              NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...              NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...              NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# 1 INDUSTRIAL AVENUE                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# Avenida Caracas                                                 NaN
# Avenida Caracas                                                 NaN
# NaN                                                             NaN
# ...                                                             ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                          NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                         NaN
# NaN                                                             NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...              NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...              NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...              NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...              NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...              NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...              NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 53, RZYMOWSKIEGO STREET                                         NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                    NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                    NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                    NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                    NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                    NaN
# NaN                                                             NaN
#
#                                                    postal_code  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...         NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...         NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...         NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...         NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...         NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# 1 INDUSTRIAL AVENUE                                     100252
# NaN                                                   2050-002
# NaN                                                       1724
# NaN                                                       1724
# NaN                                                       1724
# NaN                                                       1724
# NaN                                                       1724
# NaN                                                       1724
# Avenida Caracas                                            NaN
# Avenida Caracas                                            NaN
# NaN                                                       1724
# ...                                                        ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                    4133
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                   2140
# NaN                                                        NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...         NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...      200131
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...      200131
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...         275
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...         NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...       13920
# 53, RZYMOWSKIEGO STREET                                 02-697
# 53, RZYMOWSKIEGO STREET                                 02-697
# 53, RZYMOWSKIEGO STREET                                 02-697
# 53, RZYMOWSKIEGO STREET                                 02-697
# 53, RZYMOWSKIEGO STREET                                 02-697
# 53, RZYMOWSKIEGO STREET                                 02-697
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            498770
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            498770
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            498770
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            498770
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            498770
# NaN                                                        NaN
#
#                                                                               city  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                      BURLINGTON
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                      BURLINGTON
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                      BURLINGTON
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                      BURLINGTON
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                      BURLINGTON
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# NaN                                                               Ciudad de Panamá
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# 1 INDUSTRIAL AVENUE                                                       ILLUPEJU
# NaN                                                                       Azambuja
# NaN                                                                     Roodepoort
# NaN                                                                     Roodepoort
# NaN                                                                     Roodepoort
# NaN                                                                     Roodepoort
# NaN                                                                     Roodepoort
# NaN                                                                     Roodepoort
# Avenida Caracas                                                            Caracas
# Avenida Caracas                                                            Caracas
# NaN                                                                     Roodepoort
# ...                                                                            ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                    PRATTELN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                                   AUCKLAND
# NaN                                                                     Phnom Penh
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...                           ACCRA
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...  SHAGHAI PILOT FREE TRADE  ZONE
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...  SHAGHAI PILOT FREE TRADE  ZONE
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...                        SHANGHAI
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...                        SANTIAGO
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...                         JAKARTA
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 53, RZYMOWSKIEGO STREET                                                     WARSAW
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                             SINGAPORE
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                             SINGAPORE
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                             SINGAPORE
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                             SINGAPORE
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                             SINGAPORE
# NaN                                                                            NaN
#
#                                                                      state  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# NaN                                                                 Panamá
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# NaN                                                                    NaN
# NaN                                                                Gauteng
# NaN                                                                Gauteng
# NaN                                                                Gauteng
# NaN                                                                Gauteng
# NaN                                                                Gauteng
# NaN                                                                Gauteng
# Avenida Caracas                                     Bolivariano de Miranda
# Avenida Caracas                                     Bolivariano de Miranda
# NaN                                                                Gauteng
# ...                                                                    ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                                NaN
# NaN                                                                    NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...                     NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...                     NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...                     NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...                     NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...                     NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...                     NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# NaN                                                                    NaN
#
#                                                    country  location_type  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...      CA            NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...      CA            NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...      CA            NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...      CA            NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...      CA            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# NaN                                                    PAN            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# 1 INDUSTRIAL AVENUE                                     NG            NaN
# NaN                                                    PRT            NaN
# NaN                                                    ZAF            NaN
# NaN                                                    ZAF            NaN
# NaN                                                    ZAF            NaN
# NaN                                                    ZAF            NaN
# NaN                                                    ZAF            NaN
# NaN                                                    ZAF            NaN
# Avenida Caracas                                        VEN            NaN
# Avenida Caracas                                        VEN            NaN
# NaN                                                    ZAF            NaN
# ...                                                    ...            ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                  CH            NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                 NZ            NaN
# NaN                                                    KHM            NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...      GH            NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...      CN            NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...      CN            NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...      CN            NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...      CL            NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...      ID            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 53, RZYMOWSKIEGO STREET                                 PL            NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            SG            NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            SG            NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            SG            NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            SG            NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10            SG            NaN
# NaN                                                    NaN            NaN
#
#                                                          lat        lng  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...       NaN        NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...       NaN        NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...       NaN        NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...       NaN        NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...       NaN        NaN
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# NaN                                                  8.95242  -79.53538
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# 1 INDUSTRIAL AVENUE                                      NaN        NaN
# NaN                                                 39.07048   -8.87311
# NaN                                                -26.15929   27.87326
# NaN                                                -26.15929   27.87326
# NaN                                                -26.15929   27.87326
# NaN                                                -26.15929   27.87326
# NaN                                                -26.15929   27.87326
# NaN                                                -26.15929   27.87326
# Avenida Caracas                                     10.46098  -66.84898
# Avenida Caracas                                     10.46098  -66.84898
# NaN                                                -26.15929   27.87326
# ...                                                      ...        ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                   NaN        NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                  NaN        NaN
# NaN                                                 11.55227  104.87691
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...       NaN        NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...       NaN        NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...       NaN        NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...       NaN        NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...       NaN        NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...       NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 53, RZYMOWSKIEGO STREET                                  NaN        NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10             NaN        NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10             NaN        NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10             NaN        NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10             NaN        NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10             NaN        NaN
# NaN                                                      NaN        NaN
#
#                                                     standard_opening_times  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...                     NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# 1 INDUSTRIAL AVENUE                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# NaN                                                                    NaN
# Avenida Caracas                                                        NaN
# Avenida Caracas                                                        NaN
# NaN                                                                    NaN
# ...                                                                    ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                                 NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                                NaN
# NaN                                                                    NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...                     NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...                     NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...                     NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...                     NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...                     NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...                     NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 53, RZYMOWSKIEGO STREET                                                NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                           NaN
# NaN                                                                    NaN
#
#                                                     building_type time_zone  \
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...            NaN    UTC -5
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...            NaN    UTC -5
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...            NaN    UTC -5
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...            NaN    UTC -5
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...            NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# NaN                                                           NaN    UTC -5
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# 1 INDUSTRIAL AVENUE                                           NaN    UTC +1
# NaN                                                           NaN       UTC
# NaN                                                           NaN    UTC +2
# NaN                                                           NaN    UTC +2
# NaN                                                           NaN    UTC +2
# NaN                                                           NaN    UTC +2
# NaN                                                           NaN    UTC +2
# NaN                                                           NaN    UTC +2
# Avenida Caracas                                               NaN  UTC -4.5
# Avenida Caracas                                               NaN  UTC -4.5
# NaN                                                           NaN    UTC +2
# ...                                                           ...       ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                        NaN    UTC +1
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                       NaN   UTC +12
# NaN                                                           NaN    UTC +7
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...            NaN       UTC
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...            NaN    UTC +8
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...            NaN    UTC +8
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...            NaN    UTC +8
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...            NaN    UTC -3
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...            NaN    UTC +7
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 53, RZYMOWSKIEGO STREET                                       NaN    UTC +1
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                  NaN    UTC +8
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                  NaN    UTC +8
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                  NaN    UTC +8
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                  NaN    UTC +8
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                  NaN    UTC +8
# NaN                                                           NaN       NaN
#
#                                                     access_notes
# street
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...           NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...           NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...           NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...           NaN
# (AIR - IMPORTER ID#896922556RM0001) / 4071 NORT...           NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# 1 INDUSTRIAL AVENUE                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# Avenida Caracas                                              NaN
# Avenida Caracas                                              NaN
# NaN                                                          NaN
# ...                                                          ...
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# CROSSDOCKING NOVARTIS, SALINEN STR 63.                       NaN
# C/- DHL SUPPLY CHAIN / 22 AIRPARK DRIVE                      NaN
# NaN                                                          NaN
# GLOKALS LIMITED / PLOT NO. 5. 3 INSURANCE CLOSE...           NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...           NaN
# NO.270 MEIYUE ROAD, / NO. 15, PERSIARAN PASAK B...           NaN
# BUILDING #39 WEST 275 BA SHENG ROAD / WAI GAO Q...           NaN
# AV. ANDRES BELLO 2687 PISO 19\t / PISO 19 LAS C...           NaN
# JLN. PULOLENTUT KAV II / E4 / KAWASAN INDUSTRI ...           NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 53, RZYMOWSKIEGO STREET                                      NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                 NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                 NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                 NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                 NaN
# 15 CHANGI NORTH WAY, SSG WAREHOUSE, 02- / 10                 NaN
# NaN                                                          NaN
#
# [692 rows x 12 columns]
