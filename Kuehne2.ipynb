# %%
# %matplotlib inline
from process import get_processed_data, visualize_unknown_data
df = get_processed_data('kuehne_2.csv')
visualize_unknown_data(df)
df.head()
# Out:
# Data Cleaning
# Removing NaN columns
# LOC_KN_CITY_CODE only contains NaNs
# LOC_IATA_CITY_CODE only contains NaNs
#     LOC_TIME_ZONE LOC_TYPE                    LOC_NAME1       LOC_STREET1  \
# NaT     Etc/GMT-1       SH            S&B INTERNATIONAL    Kitmanstraat 3
# NaT     Etc/GMT-1       SH          Groupe Ponroy Sante   Parc d'Activite
# NaT           CET       CN      BRASCHLER'S COMESTIBLES   Geroldstrasse 5
# NaT     Etc/GMT-1       SH       BIORIGINAL EUROPE/ASIA        Bosland 40
# NaT     Etc/GMT-1       SH  TIBOTEC PHARMACEUTICALS LTD  Neutalstrasse 75
#
#       LOC_STREET2 LOC_ISO_COUNTRY_CODE LOC_POSTAL_CODE      LOC_CITY  \
# NaT           NaN                   NL             NaN       Alkmaar
# NaT           NaN                   FR             NaN      Bouffere
# NaT           NaN                   CH            8005       Zuerich
# NaT           NaN                   NL             NaN    Den Bommel
# NaT  C/O Cilag AG                   AT             NaN  Schaffhausen
#
#     LOC_STATE_PROVINCE
# NaT                NaN
# NaT                NaN
# NaT                NaN
# NaT                NaN
# NaT                NaN

# %%
from process import read_data
df = read_data('cleaned_and_normalized_2.csv')
visualize_unknown_data(df)
df.head()
# Out:
#                                                     street  street_addition  \
# name
# S&B INTERNATIONAL                           Kitmanstraat 3              NaN
# Groupe Ponroy Sante                       Parc d'Activite,              NaN
# BRASCHLER'S COMESTIBLES                    Geroldstrasse 5              NaN
# BIORIGINAL EUROPE/ASIA                         Bosland 40,              NaN
# TIBOTEC PHARMACEUTICALS LTD  Neutalstrasse 75,C/O Cilag AG              NaN
#
#                             postal_code          city          state country  \
# name
# S&B INTERNATIONAL               1812 PL       Alkmaar  Noord-Holland     NLD
# Groupe Ponroy Sante                 NaN      Bouffere            NaN      FR
# BRASCHLER'S COMESTIBLES            8005        Zürich             ZH     CHE
# BIORIGINAL EUROPE/ASIA              NaN    Den Bommel            NaN      NL
# TIBOTEC PHARMACEUTICALS LTD         NaN  Schaffhausen            NaN      AT
#
#                             location_type       lat      lng  \
# name
# S&B INTERNATIONAL                      SH  52.62011  4.76313
# Groupe Ponroy Sante                    SH       NaN      NaN
# BRASCHLER'S COMESTIBLES                CN  47.38567  8.52024
# BIORIGINAL EUROPE/ASIA                 SH       NaN      NaN
# TIBOTEC PHARMACEUTICALS LTD            SH       NaN      NaN
#
#                              standard_opening_times  building_type  time_zone  \
# name
# S&B INTERNATIONAL                               NaN            NaN  Etc/GMT-1
# Groupe Ponroy Sante                             NaN            NaN  Etc/GMT-1
# BRASCHLER'S COMESTIBLES                         NaN            NaN        CET
# BIORIGINAL EUROPE/ASIA                          NaN            NaN  Etc/GMT-1
# TIBOTEC PHARMACEUTICALS LTD                     NaN            NaN  Etc/GMT-1
#
#                              access_notes
# name
# S&B INTERNATIONAL                     NaN
# Groupe Ponroy Sante                   NaN
# BRASCHLER'S COMESTIBLES               NaN
# BIORIGINAL EUROPE/ASIA                NaN
# TIBOTEC PHARMACEUTICALS LTD           NaN
